# %% [markdown]
# Câu 1

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

cat_cols = {'GT', 'DT', 'KV', 'KT'}

quantitative = []
qualitative = []

for col in df.columns:
    if col in cat_cols:
        qualitative.append(col)
    elif pd.api.types.is_numeric_dtype(df[col]):
        quantitative.append(col)

print("Biến định lượng:", quantitative)
print("Biến định tính:", qualitative)
# Out:
# Biến định lượng: ['STT', 'T1', 'L1', 'H1', 'S1', 'V1', 'X1', 'D1', 'N1', 'T2', 'L2', 'H2', 'S2', 'V2', 'X2', 'D2', 'N2', 'T3', 'L3', 'H3', 'S3', 'V3', 'X3', 'D3', 'N3', 'T4', 'L4', 'H4', 'S4', 'V4', 'X4', 'D4', 'N4', 'T5', 'L5', 'H5', 'S5', 'V5', 'X5', 'D5', 'N5', 'T6', 'L6', 'H6', 'S6', 'V6', 'X6', 'D6', 'N6', 'DH1', 'DH2', 'DH3']
# Biến định tính: ['GT', 'DT', 'KV', 'KT']

# %% [markdown]
# Câu 2

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

scale = {}

for col in df.columns:
    if col in ['GT', 'DT', 'KT']:
        scale[col] = "Danh nghĩa (Nominal)"
    elif col == 'KV':
        scale[col] = "Thứ bậc (Ordinal)"
    else:
        scale[col] = "Khoảng (Interval)"

pd.DataFrame(list(scale.items()), columns=["Tên biến", "Thang đo"])
# Out:
#    Tên biến              Thang đo
# 0       STT     Khoảng (Interval)
# 1        T1     Khoảng (Interval)
# 2        L1     Khoảng (Interval)
# 3        H1     Khoảng (Interval)
# 4        S1     Khoảng (Interval)
# 5        V1     Khoảng (Interval)
# 6        X1     Khoảng (Interval)
# 7        D1     Khoảng (Interval)
# 8        N1     Khoảng (Interval)
# 9        T2     Khoảng (Interval)
# 10       L2     Khoảng (Interval)
# 11       H2     Khoảng (Interval)
# 12       S2     Khoảng (Interval)
# 13       V2     Khoảng (Interval)
# 14       X2     Khoảng (Interval)
# 15       D2     Khoảng (Interval)
# 16       N2     Khoảng (Interval)
# 17       T3     Khoảng (Interval)
# 18       L3     Khoảng (Interval)
# 19       H3     Khoảng (Interval)
# 20       S3     Khoảng (Interval)
# 21       V3     Khoảng (Interval)
# 22       X3     Khoảng (Interval)
# 23       D3     Khoảng (Interval)
# 24       N3     Khoảng (Interval)
# 25       T4     Khoảng (Interval)
# ...

# %% [markdown]
# Câu 3

# %%
import pandas as pd
df = pd.read_csv("dulieuxettuyendaihoc.csv")
print("10 dòng đầu:")
print(df.head(10))
print("\n10 dòng cuối:")
print(df.tail(10))
# Out:
# 10 dòng đầu:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   X6   D6   N6  GT  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  6.6  7.6  5.9   F
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  6.6  6.1  4.4   M
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  7.9  8.1  4.6   M
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  7.1  7.3  7.4   M
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.1  7.5  7.2   M
# 5    6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  5.7  8.0  7.8   M
# 6    7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  6.6  6.0  6.0   F
# 7    8  8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  ...  7.1  6.8  7.0   F
# 8    9  6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  ...  9.1  7.9  6.1   F
# 9   10  7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  ...  6.4  6.1  7.8   F
#
#    DT   KV   DH1   DH2   DH3  KT
# 0 NaN  2NT  3.25  3.25  4.50  A1
# 1 NaN    1  6.00  4.00  3.50   C
# ...

# %% [markdown]
# Câu 4

# %%
import pandas as pd
df = pd.read_csv("dulieuxettuyendaihoc.csv")
print("Số giá trị thiếu DT:", df['DT'].isna().sum())
print("\nBảng tần số DT:")
print(df['DT'].value_counts(dropna=False))
print("\nBảng tần suất DT:")
print(df['DT'].value_counts(normalize=True, dropna=False))
print("\nSố giá trị DT riêng biệt:", df['DT'].nunique(dropna=False))
df['DT'] = df['DT'].fillna(0)
print("\nSau khi điền, số giá trị thiếu DT:", df['DT'].isna().sum())
# Out:
# Số giá trị thiếu DT: 97
#
# Bảng tần số DT:
# DT
# NaN    97
# 1.0     2
# 6.0     1
# Name: count, dtype: int64
#
# Bảng tần suất DT:
# DT
# NaN    0.97
# 1.0    0.02
# 6.0    0.01
# Name: proportion, dtype: float64
#
# Số giá trị DT riêng biệt: 3
#
# Sau khi điền, số giá trị thiếu DT: 0

# %% [markdown]
# Câu 5

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

t1 = df['T1']

missing = t1.isna().sum()
freq = t1.value_counts(dropna=False)
ratio = t1.value_counts(dropna=False, normalize=True)
mean_value = t1.mean()

print(f"Số giá trị thiếu T1: {missing}")
print("\nBảng tần số T1:")
print(freq)
print("\nBảng tần suất T1:")
print(ratio)

df.loc[t1.isna(), 'T1'] = mean_value

print(f"\nGiá trị Mean của T1: {mean_value}")
print("Sau khi điền, số giá trị thiếu T1:", df['T1'].isna().sum())
# Out:
# Số giá trị thiếu T1: 0
#
# Bảng tần số T1:
# T1
# 5.2    5
# 7.3    5
# 5.3    5
# 6.0    4
# 7.2    4
# 7.9    4
# 4.9    3
# 5.4    3
# 5.0    3
# 8.2    3
# 6.5    3
# 5.5    3
# 6.3    3
# 8.8    2
# 7.1    2
# 8.3    2
# 6.4    2
# 3.6    2
# 8.1    2
# 6.6    2
# 5.6    2
# 5.7    2
# 5.8    2
# 3.0    2
# 5.1    2
# 9.3    1
# 3.9    1
# 2.5    1
# 2.8    1
# 2.4    1
# 3.4    1
# 4.3    1
# 4.4    1
# 4.7    1
# 4.5    1
# 2.6    1
# 7.6    1
# 6.7    1
# 6.9    1
# 6.1    1
# 7.0    1
# 6.2    1
# 4.6    1
# 4.2    1
# 7.5    1
# 4.8    1
# 5.9    1
# 8.4    1
# 7.8    1
# 8.6    1
# 3.7    1
# 2.7    1
# 4.1    1
# Name: count, dtype: int64
#
# Bảng tần suất T1:
# T1
# 5.2    0.05
# 7.3    0.05
# 5.3    0.05
# 6.0    0.04
# 7.2    0.04
# 7.9    0.04
# 4.9    0.03
# 5.4    0.03
# 5.0    0.03
# 8.2    0.03
# 6.5    0.03
# 5.5    0.03
# 6.3    0.03
# 8.8    0.02
# 7.1    0.02
# 8.3    0.02
# 6.4    0.02
# 3.6    0.02
# 8.1    0.02
# 6.6    0.02
# 5.6    0.02
# 5.7    0.02
# ...

# %% [markdown]
# Câu 6

# %%
import pandas as pd
df = pd.read_csv("dulieuxettuyendaihoc.csv")
score_cols = [c for c in df.columns
              if c not in ['GT', 'DT', 'KV', 'KT'] and pd.api.types.is_numeric_dtype(df[c])]
for col in score_cols:
    if df[col].isna().sum() > 0:
        mean_val = df[col].mean()
        df[col] = df[col].fillna(mean_val)
        print(f"{col}: điền {mean_val:.2f}")

print("\nTổng số dữ liệu thiếu còn lại:", df.isna().sum().sum())
# Out:
# Tổng số dữ liệu thiếu còn lại: 97

# %% [markdown]
# Câu 7

# %%
import pandas as pd
df = pd.read_csv("dulieuxettuyendaihoc.csv")
df['TBM1'] = (df['T1']*2 + df['L1'] + df['H1'] + df['S1'] +
              df['V1']*2 + df['X1'] + df['D1'] + df['N1']) / 10
df['TBM2'] = (df['T2']*2 + df['L2'] + df['H2'] + df['S2'] +
              df['V2']*2 + df['X2'] + df['D2'] + df['N2']) / 10
df['TBM3'] = (df['T6']*2 + df['L6'] + df['H6'] + df['S6'] +
              df['V6']*2 + df['X6'] + df['D6'] + df['N6']) / 10
print(df[['TBM1', 'TBM2', 'TBM3']].head())
# Out:
#    TBM1  TBM2  TBM3
# 0  7.00  7.54  7.01
# 1  4.69  5.47  5.07
# 2  5.77  5.38  6.04
# 3  6.21  5.20  6.88
# 4  6.50  6.36  6.99

# %% [markdown]
# Câu 8

# %%
def xep_loai(tbm):
    if tbm < 5:
        return 'Y'
    elif tbm < 6.5:
        return 'TB'
    elif tbm < 8:
        return 'K'
    elif tbm < 9:
        return 'G'
    else:
        return 'XS'
df['XL1'] = df['TBM1'].apply(xep_loai)
df['XL2'] = df['TBM2'].apply(xep_loai)
df['XL3'] = df['TBM3'].apply(xep_loai)

print(df[['XL1', 'XL2', 'XL3']].head())
# Out:
#   XL1 XL2 XL3
# 0   K   K   K
# 1   Y  TB  TB
# 2  TB  TB  TB
# 3  TB  TB   K
# 4   K  TB   K

# %% [markdown]
# Câu 9

# %%
for i in [1, 2, 3]:
    col = f'TBM{i}'
    df[f'US_TBM{i}'] = (df[col] - df[col].min()) / (df[col].max() - df[col].min()) * 4

print(df[['US_TBM1', 'US_TBM2', 'US_TBM3']].head())
# Out:
#     US_TBM1   US_TBM2   US_TBM3
# 0  2.930693  3.029126  2.537143
# 1  0.643564  1.019417  0.320000
# 2  1.712871  0.932039  1.428571
# 3  2.148515  0.757282  2.388571
# 4  2.435644  1.883495  2.514286

# %% [markdown]
# Câu 10

# %%
def xet_tuyen(row):
    if row['KT'] in ['A', 'A1']:
        diem = (row['DH1']*2 + row['DH2'] + row['DH3']) / 4
    elif row['KT'] == 'B':
        diem = (row['DH1'] + row['DH2']*2 + row['DH3']) / 4
    else:
        diem = (row['DH1'] + row['DH2'] + row['DH3']) / 3
    return 1 if diem >= 5 else 0

df['KQXT'] = df.apply(xet_tuyen, axis=1)

print(df[['KT', 'DH1', 'DH2', 'DH3', 'KQXT']].head())
# Out:
#    KT   DH1   DH2   DH3  KQXT
# 0  A1  3.25  3.25  4.50     0
# 1   C  6.00  4.00  3.50     0
# 2   C  5.00  6.75  4.00     1
# 3  D1  4.25  4.25  5.25     0
# 4   A  4.25  4.50  5.00     0

# %% [markdown]
# Câu 11

# %%
df.to_csv("processed_dulieuxettuyendaihoc.csv", index=False)
